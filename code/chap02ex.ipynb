# %% [markdown]
# Exercise from Think Stats, 2nd Edition (thinkstats2.com)<br>
# Allen Downey
#
# Read the female respondent file and display the variables names.

# %%
# %matplotlib inline

import chap01soln
resp = chap01soln.ReadFemResp()
resp.columns
# Out:
# Index(['caseid', 'rscrinf', 'rdormres', 'rostscrn', 'rscreenhisp',
#        'rscreenrace', 'age_a', 'age_r', 'cmbirth', 'agescrn',
#        ...
#        'pubassis_i', 'basewgt', 'adj_mod_basewgt', 'finalwgt', 'secu_r',
#        'sest', 'cmintvw', 'cmlstyr', 'screentime', 'intvlngth'],
#       dtype='object', length=3087)

# %% [markdown]
# Make a histogram of <tt>totincr</tt> the total income for the respondent's family.  To interpret the codes see the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=MALE&section=R&subSec=7958&srtLabel=609776).

# %%
import thinkstats2
import thinkplot

hist = thinkstats2.Hist(resp.totincr, label="totincr")

# %% [markdown]
# Display the histogram.

# %%
import thinkplot
thinkplot.Hist(hist)
thinkplot.Show(xlabel="total income", ylabel="frequency")

# %% [markdown]
# Make a histogram of <tt>age_r</tt>, the respondent's age at the time of interview.

# %%
hist = thinkstats2.Hist(resp.age_r, label="age_r")
thinkplot.Hist(hist)
thinkplot.Show(xlabel='age', ylabel='frequency')

# %% [markdown]
# Make a histogram of <tt>numfmhh</tt>, the number of people in the respondent's household.

# %%
hist = thinkstats2.Hist(resp.numfmhh, label="numfmhh")
thinkplot.Hist(hist)
thinkplot.Show(xlabel='number of people in the household', label='frequency')

# %% [markdown]
# Make a histogram of <tt>parity</tt>, the number children the respondent has borne.  How would you describe this distribution?

# %%
hist = thinkstats2.Hist(resp.parity, label="parity")
thinkplot.Hist(hist)
thinkplot.Show(xlabel='number children the respondent has borne', ylabel='frequency')

# %% [markdown]
# Use Hist.Largest to find the largest values of <tt>parity</tt>.

# %%
hist.Largest()
# Out:
# [(22, 1),
#  (16, 1),
#  (10, 3),
#  (9, 2),
#  (8, 8),
#  (7, 15),
#  (6, 29),
#  (5, 95),
#  (4, 309),
#  (3, 828)]

# %% [markdown]
# Use <tt>totincr</tt> to select the respondents with the highest income.  Compute the distribution of <tt>parity</tt> for just the high income respondents.

# %%
richest = resp.totincr.max()
rich = resp[resp.totincr == richest]
hist = thinkstats2.Hist(rich.parity, label="parity for high income respondents")
thinkplot.Hist(hist)
thinkplot.Show(xlabel='parity', ylabel='frequency')

# %% [markdown]
# Find the largest parities for high income respondents.

# %%
hist.Largest()
# Out:
# [(8, 1), (7, 1), (5, 5), (4, 19), (3, 123), (2, 267), (1, 229), (0, 515)]

# %% [markdown]
# Compare the mean <tt>parity</tt> for high income respondents and others.

# %%
import thinkstats2

others = resp[resp.totincr != richest]
print("rich:", rich.parity.mean()) 
print("others:", others.parity.mean())

effect_size = thinkstats2.CohenEffectSize(rich.parity, others.parity)
print("Cohen d effect size:", effect_size)
# Out:
# rich: 1.0758620689655172
# others: 1.2495758136665125
# Cohen d effect size: -0.1251185531466061

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
hist = thinkstats2.Hist(resp.abortion)
thinkplot.Hist(hist, label="abortion")
thinkplot.Show()
